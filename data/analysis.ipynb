# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('news.csv')
df
# Out:
#         ID                                              Title  \
# 0        1  Candy factory didn't evacuate concerned worker...
# 1        2  Baltimore police ask for public's help identif...
# 2        3  An arrest warrant has been issued for a suspec...
# 3        4  115 improperly stored human remains found in C...
# 4        5  Bronx day care provider and 2 others indicted ...
# ...    ...                                                ...
# 4107  4108  McCarthy commits to key concession in call wit...
# 4108  4109  What to know about the suspected Chinese spy b...
# 4109  4110  Why the US hasn't shot down the suspected Chin...
# 4110  4111  Chinese engineer sentenced to 8 years in US pr...
# 4111  4112  Tensions mount at the Belarus-Ukraine border a...
#
#                                             Description  \
# 0     An eastern Pennsylvania candy factory didn’t e...
# 1     Two shooters were involved in an attack at Mor...
# ...

# %%
queries = [
    'Please describe the explosion happened in Pennsylvania in March 2023.',
    'Do you know the casualties and economic losses caused by the floods in Libya？',
    'Did Turkey approve Finland’s application to join NATO?'
]

# %%
test_data = pd.DataFrame(columns=['query'], data=queries)
test_data
# Out:
#                                                query
# 0  Please describe the explosion happened in Penn...
# 1  Do you know the casualties and economic losses...
# 2  Did Turkey approve Finland’s application to jo...

# %%
test_data.to_csv('test.csv')
